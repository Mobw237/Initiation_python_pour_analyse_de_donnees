# %% [markdown]
# <a href="https://colab.research.google.com/github/Mobw237/Initiation_python_pour_analyse_de_donnees/blob/main/notebooks/P3C1%20exo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![openclassrooms](https://s3.eu-west-1.amazonaws.com/course.oc-static.com/courses/6204541/1+HnqdJ-5ofxiPP9HIxdNdpw.jpeg)
#
# # Initiez-vous à Python pour l'analyse de données
#
# ## Créez des tableaux pour stocker vos variables
#
# <br><br>
#
# **Ajouter des éléments à une liste**
#
# Remplacez les **??** par le code adéquat pour créer une liste vide :

# %%
invites = []

# %% [markdown]
# Ajoutez 3 invités à la liste : Joey, Martin et Marie

# %%
invites.append("Joey")
invites.append("Martin")
invites.append("Marie")

# %% [markdown]
# Affichez la taille de la liste :

# %%
len(invites)
# Out:
# 3

# %% [markdown]
# Remplacez Martin par John dans la liste :

# %%
invites[1] = 'John'

# %% [markdown]
# Supprimez Joey de la liste :

# %%
invites.remove('Joey')

# %% [markdown]
# Affichez le contenu de la liste :

# %%
for invite in invites :
    print(invite)
# Out:
# John
# Marie
